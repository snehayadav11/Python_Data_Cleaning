# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import datetime as dt

# %%
airbnb=pd.read_csv("airbnb.csv")

# %%
airbnb.head()
# Out:
#    Unnamed: 0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
# 3           3     6425850                          Spacious, charming studio
# 4           4    22986519              Bedroom on the lively Lower East Side
#
#      host_id host_name          neighbourhood_full            coordinates  \
# 0   20583125    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1   82746113   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
# 2      78251    Leslie  Brooklyn, Brooklyn Heights   (40.7007, -73.99517)
# 3   32715865    Yelena  Manhattan, Upper West Side  (40.79169, -73.97498)
# 4  154262349    Brooke  Manhattan, Lower East Side  (40.71884, -73.98354)
#
# ...

# %%
airbnb.dtypes
# Out:
# Unnamed: 0              int64
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# coordinates            object
# room_type              object
# price                  object
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# dtype: object

# %%
airbnb.drop(['Unnamed: 0'],axis=1)
# Out:
#        listing_id                                               name  \
# 0        13740704  Cozy,budget friendly, cable inc, private entra...
# 1        22005115              Two floor apartment near Central Park
# 2        21667615                  Beautiful 1BR in Brooklyn Heights
# 3         6425850                          Spacious, charming studio
# 4        22986519              Bedroom on the lively Lower East Side
# ...           ...                                                ...
# 10014    22307861                        Lovely 1BR Harlem apartment
# 10015      953275                Apartment For Your Holidays in NYC!
# 10016     3452835          Artsy, Garden Getaway in Central Brooklyn
# 10017    23540194     Immaculate townhouse in Clinton Hill, Brooklyn
# 10018    32876011     Private room in a perfect location in the city
#
#          host_id host_name          neighbourhood_full  \
# 0       20583125    Michel         Brooklyn, Flatlands
# ...

# %%
airbnb=airbnb.drop(['Unnamed: 0'],axis=1)

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name          neighbourhood_full            coordinates  \
# 0    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
# 2    Leslie  Brooklyn, Brooklyn Heights   (40.7007, -73.99517)
# 3    Yelena  Manhattan, Upper West Side  (40.79169, -73.97498)
# 4    Brooke  Manhattan, Lower East Side  (40.71884, -73.98354)
#
#          room_type price  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   listing_id          10019 non-null  int64
#  1   name                10014 non-null  object
#  2   host_id             10019 non-null  int64
#  3   host_name           10017 non-null  object
#  4   neighbourhood_full  10019 non-null  object
#  5   coordinates         10019 non-null  object
#  6   room_type           10019 non-null  object
#  7   price               9781 non-null   object
#  8   number_of_reviews   10019 non-null  int64
#  9   last_review         7944 non-null   object
#  10  reviews_per_month   7944 non-null   float64
#  11  availability_365    10019 non-null  int64
#  12  rating              7944 non-null   float64
#  13  number_of_stays     7944 non-null   float64
#  14  5_stars             7944 non-null   float64
# ...

# %%
airbnb.isna().sum()
# Out:
# listing_id               0
# name                     5
# host_id                  0
# host_name                2
# neighbourhood_full       0
# coordinates              0
# room_type                0
# price                  238
# number_of_reviews        0
# last_review           2075
# reviews_per_month     2075
# availability_365         0
# rating                2075
# number_of_stays       2075
# 5_stars               2075
# listing_added            0
# dtype: int64

# %%
airbnb.describe()
# Out:
#          listing_id       host_id  number_of_reviews  reviews_per_month  \
# count  1.001900e+04  1.001900e+04       10019.000000        7944.000000
# mean   1.927634e+07  6.795923e+07          22.459727           1.353894
# std    1.095056e+07  7.863106e+07          43.173896           1.615380
# min    3.831000e+03  2.787000e+03           0.000000           0.010000
# 25%    9.674772e+06  7.910880e+06           1.000000           0.200000
# 50%    2.007030e+07  3.165167e+07           5.000000           0.710000
# 75%    2.933864e+07  1.074344e+08          22.000000           2.000000
# max    3.648724e+07  2.741034e+08         510.000000          16.220000
#
#        availability_365       rating  number_of_stays      5_stars
# count      10019.000000  7944.000000      7944.000000  7944.000000
# mean         112.284260     4.014458        33.991541     0.718599
# std          131.636043     0.575064        56.089279     0.079978
# ...

# %%
airbnb['coordinates']=airbnb['coordinates'].str.replace("(","")
airbnb['coordinates']=airbnb['coordinates'].str.replace(")","")
airbnb['coordinates'].head()
# Out:
# 0    40.63222, -73.93398
# 1    40.78761, -73.96862
# 2     40.7007, -73.99517
# 3    40.79169, -73.97498
# 4    40.71884, -73.98354
# Name: coordinates, dtype: object

# %%
newdata=airbnb['coordinates'].str.split(",",expand=True)
newdata.head()
# Out:
#           0           1
# 0  40.63222   -73.93398
# 1  40.78761   -73.96862
# 2   40.7007   -73.99517
# 3  40.79169   -73.97498
# 4  40.71884   -73.98354

# %%
newdata[0]
# Out:
# 0        40.63222
# 1        40.78761
# 2         40.7007
# 3        40.79169
# 4        40.71884
#            ...
# 10014    40.80379
# 10015    40.79531
# 10016    40.68266
# 10017    40.68832
# 10018    40.76174
# Name: 0, Length: 10019, dtype: object

# %%
airbnb["latitude"]=newdata[0]
airbnb["longitude"]=newdata[1]

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name          neighbourhood_full          coordinates        room_type  \
# 0    Michel         Brooklyn, Flatlands  40.63222, -73.93398     Private room
# 1   Cecilia  Manhattan, Upper West Side  40.78761, -73.96862  Entire home/apt
# 2    Leslie  Brooklyn, Brooklyn Heights   40.7007, -73.99517  Entire home/apt
# 3    Yelena  Manhattan, Upper West Side  40.79169, -73.97498  Entire home/apt
# 4    Brooke  Manhattan, Lower East Side  40.71884, -73.98354     Private room
#
# ...

# %%
airbnb.dtypes
# Out:
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# coordinates            object
# room_type              object
# price                  object
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# latitude               object
# longitude              object
# dtype: object

# %%
airbnb["latitude"]=airbnb["latitude"].astype("float")
airbnb["longitude"]=airbnb["longitude"].astype("float")

# %%
airbnb.dtypes
# Out:
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# coordinates            object
# room_type              object
# price                  object
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# latitude              float64
# longitude             float64
# dtype: object

# %%
airbnb=airbnb.drop("coordinates",axis=1)

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name          neighbourhood_full        room_type price  \
# 0    Michel         Brooklyn, Flatlands     Private room   45$
# 1   Cecilia  Manhattan, Upper West Side  Entire home/apt  135$
# 2    Leslie  Brooklyn, Brooklyn Heights  Entire home/apt  150$
# 3    Yelena  Manhattan, Upper West Side  Entire home/apt   86$
# 4    Brooke  Manhattan, Lower East Side     Private room  160$
#
#    number_of_reviews last_review  reviews_per_month  availability_365  \
# ...

# %%
airbnb['price']=airbnb['price'].str.strip("$")
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name          neighbourhood_full        room_type price  \
# 0    Michel         Brooklyn, Flatlands     Private room    45
# 1   Cecilia  Manhattan, Upper West Side  Entire home/apt   135
# 2    Leslie  Brooklyn, Brooklyn Heights  Entire home/apt   150
# 3    Yelena  Manhattan, Upper West Side  Entire home/apt    86
# 4    Brooke  Manhattan, Lower East Side     Private room   160
#
#    number_of_reviews last_review  reviews_per_month  availability_365  \
# ...

# %%
airbnb['price']=airbnb['price'].astype("float")

# %%
airbnb.dtypes
# Out:
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# room_type              object
# price                 float64
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# latitude              float64
# longitude             float64
# dtype: object

# %%
Data=airbnb['neighbourhood_full'].str.split(",",expand=True)

# %%
Data.head()
# Out:
#            0                  1
# 0   Brooklyn          Flatlands
# 1  Manhattan    Upper West Side
# 2   Brooklyn   Brooklyn Heights
# 3  Manhattan    Upper West Side
# 4  Manhattan    Lower East Side

# %%
airbnb['neighbourhood1']=Data[0]
airbnb['neighbourhood2']=Data[1]

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name          neighbourhood_full        room_type  price  \
# 0    Michel         Brooklyn, Flatlands     Private room   45.0
# 1   Cecilia  Manhattan, Upper West Side  Entire home/apt  135.0
# 2    Leslie  Brooklyn, Brooklyn Heights  Entire home/apt  150.0
# 3    Yelena  Manhattan, Upper West Side  Entire home/apt   86.0
# 4    Brooke  Manhattan, Lower East Side     Private room  160.0
#
#    number_of_reviews last_review  reviews_per_month  availability_365  \
# ...

# %%
airbnb=airbnb.drop(['neighbourhood_full'],axis=1)

# %%
duplicates=airbnb.duplicated(subset='listing_id',keep=False)

# %%
duplicates.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
print(duplicates)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10014    False
# 10015    False
# 10016    False
# 10017    False
# 10018    False
# Length: 10019, dtype: bool

# %%
airbnb.to_csv('AirbnbRefined1.csv')

# %%
airbnb[airbnb['rating'].isna()].describe()
# Out:
#          listing_id       host_id        price  number_of_reviews  \
# count  2.075000e+03  2.075000e+03  2028.000000             2075.0
# mean   2.274238e+07  8.022455e+07   191.553748                0.0
# std    1.123730e+07  8.663163e+07   316.186639                0.0
# min    6.358800e+04  1.475100e+04     0.000000                0.0
# 25%    1.232923e+07  1.224305e+07    70.000000                0.0
# 50%    2.345182e+07  4.040116e+07   120.000000                0.0
# 75%    3.400364e+07  1.333498e+08   205.250000                0.0
# max    3.648724e+07  2.741034e+08  5250.000000                0.0
#
#        reviews_per_month  availability_365  rating  number_of_stays  5_stars  \
# count                0.0       2075.000000     0.0              0.0      0.0
# mean                 NaN        104.531566     NaN              NaN      NaN
# std                  NaN        138.266525     NaN              NaN      NaN
# ...

# %%
airbnb[~airbnb['rating'].isna()].describe()
# Out:
#          listing_id       host_id        price  number_of_reviews  \
# count  7.944000e+03  7.944000e+03  7753.000000        7944.000000
# mean   1.837100e+07  6.475548e+07   140.272411          28.326284
# std    1.069161e+07  7.608428e+07   163.668464          46.741066
# min    3.831000e+03  2.787000e+03     0.000000           1.000000
# 25%    8.970241e+06  7.137797e+06    69.000000           3.000000
# 50%    1.928118e+07  2.949374e+07   105.000000           9.000000
# 75%    2.789420e+07  1.016715e+08   170.000000          32.000000
# max    3.641363e+07  2.733615e+08  8000.000000         510.000000
#
#        reviews_per_month  availability_365       rating  number_of_stays  \
# count        7944.000000       7944.000000  7944.000000      7944.000000
# mean            1.353894        114.309290     4.014458        33.991541
# std             1.615380        129.781153     0.575064        56.089279
# min             0.010000          0.000000     3.000633         1.200000
# ...

# %%
airbnb=airbnb.fillna({'reviews_per_month':0,'number_of_stays':0,'5_stars':0})

# %%
airbnb.isna().sum()
# Out:
# listing_id              0
# name                    5
# host_id                 0
# host_name               2
# room_type               0
# price                 238
# number_of_reviews       0
# last_review          2075
# reviews_per_month       0
# availability_365        0
# rating               2075
# number_of_stays         0
# 5_stars                 0
# listing_added           0
# latitude                0
# longitude               0
# neighbourhood1          0
# neighbourhood2          0
# dtype: int64

# %%
new_rating=np.where(airbnb['rating'].isna()==True,0,1)
airbnb['new_ratings']=new_rating

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name        room_type  price  number_of_reviews last_review  \
# 0    Michel     Private room   45.0                 10  2018-12-12
# 1   Cecilia  Entire home/apt  135.0                  1  2019-06-30
# 2    Leslie  Entire home/apt  150.0                  0         NaN
# 3    Yelena  Entire home/apt   86.0                  5  2017-09-23
# 4    Brooke     Private room  160.0                 23  2019-06-12
#
#    reviews_per_month  availability_365    rating  number_of_stays   5_stars  \
# ...

# %%
airbnb.groupby('room_type').median(numeric_only=True)['price']
# Out:
# room_type
#    Shared room           49.0
# Entire home/apt         163.0
# PRIVATE ROOM             73.0
# Private                  75.0
# Private room             70.0
# Shared room              50.0
# home                    170.0
# Name: price, dtype: float64

# %%
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='Entire home/apt'),'price']=163.0 
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='PRIVATE ROOM'),'price']=73.0 
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='Private'),'price']=75.0 
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='Private room'),'price']=70.0 
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='Shared room'),'price']=50.0 
airbnb.loc[(airbnb['price'].isna())&(airbnb['room_type']=='home'),'price']=170.0

# %%
airbnb.isna().sum()
# Out:
# listing_id              0
# name                    5
# host_id                 0
# host_name               2
# room_type               0
# price                   2
# number_of_reviews       0
# last_review          2075
# reviews_per_month       0
# availability_365        0
# rating               2075
# number_of_stays         0
# 5_stars                 0
# listing_added           0
# latitude                0
# longitude               0
# neighbourhood1          0
# neighbourhood2          0
# new_ratings             0
# dtype: int64

# %%
airbnb.to_csv("Airbnb.csv")

# %%
airbnb.head()
# Out:
#    listing_id                                               name    host_id  \
# 0    13740704  Cozy,budget friendly, cable inc, private entra...   20583125
# 1    22005115              Two floor apartment near Central Park   82746113
# 2    21667615                  Beautiful 1BR in Brooklyn Heights      78251
# 3     6425850                          Spacious, charming studio   32715865
# 4    22986519              Bedroom on the lively Lower East Side  154262349
#
#   host_name        room_type  price  number_of_reviews last_review  \
# 0    Michel     Private room   45.0                 10  2018-12-12
# 1   Cecilia  Entire home/apt  135.0                  1  2019-06-30
# 2    Leslie  Entire home/apt  150.0                  0         NaN
# 3    Yelena  Entire home/apt   86.0                  5  2017-09-23
# 4    Brooke     Private room  160.0                 23  2019-06-12
#
#    reviews_per_month  availability_365    rating  number_of_stays   5_stars  \
# ...

# %%
airbnb.to_csv("airbnb1.csv")
